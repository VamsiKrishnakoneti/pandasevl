# %%
pip install pymysql
# Out:
# ...
#
# ...

# %%
import mysql.connector


conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="Vamsi@2005",
    database="classicmodels"
)

cursor = db_connection.cursor()

# %%
cursor = conn.cursor()

# %%
cursor.execute("Select * from orderdetails;")

# %%
result = cursor.fetchall();

# %%
for i in result:
    print(i)
# Out:
# (10100, 'S18_1749', 30, Decimal('136.00'), 3)
# (10100, 'S18_2248', 50, Decimal('55.09'), 2)
# (10100, 'S18_4409', 22, Decimal('75.46'), 4)
# (10100, 'S24_3969', 49, Decimal('35.29'), 1)
# (10101, 'S18_2325', 25, Decimal('108.06'), 4)
# (10101, 'S18_2795', 26, Decimal('167.06'), 1)
# (10101, 'S24_1937', 45, Decimal('32.53'), 3)
# (10101, 'S24_2022', 46, Decimal('44.35'), 2)
# (10102, 'S18_1342', 39, Decimal('95.55'), 2)
# (10102, 'S18_1367', 41, Decimal('43.13'), 1)
# (10103, 'S10_1949', 26, Decimal('214.30'), 11)
# (10103, 'S10_4962', 42, Decimal('119.67'), 4)
# (10103, 'S12_1666', 27, Decimal('121.64'), 8)
# (10103, 'S18_1097', 35, Decimal('94.50'), 10)
# (10103, 'S18_2432', 22, Decimal('58.34'), 2)
# (10103, 'S18_2949', 27, Decimal('92.19'), 12)
# (10103, 'S18_2957', 35, Decimal('61.84'), 14)
# (10103, 'S18_3136', 25, Decimal('86.92'), 13)
# (10103, 'S18_3320', 46, Decimal('86.31'), 16)
# (10103, 'S18_4600', 36, Decimal('98.07'), 5)
# (10103, 'S18_4668', 41, Decimal('40.75'), 9)
# ...

# %%
##cursor.execute("insert into orderdetails values(10100, 's19_1789', '40', '142.34', 4)")

# %%
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine

# %%
engine = sqlalchemy.create_engine('mysql+pymysql://root Vamsi@2005:@localhost:3306/classicmodels')

# %%
query = "select orderNumber,sum(quantityOrdered) as q,sum(quantityOrdered*priceEach) as revenue from orderdetails group by orderNumber"
df = pd.read_sql(query,conn)
# Out:
# C:\Users\vvams\AppData\Local\Temp\ipykernel_2212\761615505.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query,conn)

# %%
df
# Out:
#      orderNumber      q   revenue
# 0          10100  151.0  10223.83
# 1          10101  142.0  10549.01
# 2          10102   80.0   5494.78
# 3          10103  541.0  50218.95
# 4          10104  443.0  40206.20
# ..           ...    ...       ...
# 321        10421   75.0   7639.10
# 322        10422   76.0   5849.44
# 323        10423  111.0   8597.73
# 324        10424  269.0  29310.30
# 325        10425  427.0  41623.44
#
# [326 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt


df.plot(kind='bar', x='orderNumber', y='revenue')


plt.show()

# %%
 plt.savefig("sales_chart.png")
